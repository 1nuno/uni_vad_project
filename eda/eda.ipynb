# %%
import pandas as pd

# %%
lawyers = pd.read_csv("../data/lawyers.csv")
lawyers
# Out:
#       Regional Council           Locality Registration Date  \
# 0              Madeira            FUNCHAL        05-11-2024
# 1              Madeira  CALHETA (MADEIRA)        19-04-1999
# 2              Madeira            FUNCHAL        04-09-2024
# 3              Madeira            FUNCHAL        07-07-2016
# 4              Madeira            FUNCHAL        01-02-2021
# ...                ...                ...               ...
# 36960           Lisboa        PORTO SALVO        04-12-2024
# 36961            Porto              PORTO        25-11-2024
# 36962           Lisboa      SÃO FRANCISCO        17-09-2024
# 36963           Lisboa             LISBOA        09-10-2023
# 36964           Lisboa             LISBOA        09-10-2023
#
#                                                  Address  \
# 0                              R da Alfândega, 64 - 3º F
# 1      ER 222 - Estr da Calheta - Estrela, 699 - Edf ...
# 2      R das Hortas, 1 - 4º, Sl 405/407 Edf do Carmo ...
# ...

# %%
societies = pd.read_csv("../data/societies.csv")
societies
# Out:
#      Regional Council Registry           Locality Date of Constitution  \
# 0               Porto    42/96         MATOSINHOS           23-07-1996
# 1               Porto    79/08              BRAGA           18-11-2008
# 2               Porto    14/05  CELORICO DE BASTO           02-02-2005
# 3               Porto     2/86              PORTO           10-03-1986
# 4               Porto    55/14              TROFA           31-10-2014
# ...               ...      ...                ...                  ...
# 1336           Açores    39/19              HORTA           02-09-2019
# 1337           Açores    28/22      PONTA DELGADA           25-07-2022
# 1338           Açores    18/10  ANGRA DO HEROÍSMO           12-02-2010
# 1339           Açores    74/08      PONTA DELGADA           10-11-2008
# 1340           Açores    33/02              HORTA           08-04-2002
#
#                                        Email  \
# 0                sociedade-advogados@clix.pt
# ...
